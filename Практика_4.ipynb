# %% [markdown]
# Практика 4

# %% [markdown]
# # О формате сдачи
#
# 🔷 **<font color='plum'>При решении ноутбука используйте данный шаблон</font>**
#
#     ✅ Можно добавлять новые ячейки любых типов
#     ❌ Не нужно удалять текстовые ячейки c разметкой частей ноутбука и формулировками заданий
#
#
# 🔷 **<font color='plum'>При оценивании задач учитывается код</font>**
#
#     ✅ Задания, в которых необходим код, обычно помечаются фразами "Your code here"/"Ваш код" и аналогичными
#     ❌ Ответы на вопросы без сопутствующего кода оцениваются в 0 баллов
#     ❌ Наличе работоспособного кода в ноутбуке, если на сказано иного, обязательно
#
# 🔷 **<font color='plum'>При оценивании задач учитываются выводы</font>**
#
#     ✅ Задания, в которых необходимы выводы, обычно помечаются фразами Вывод"/"Ответ на вопрос"/"Ваш текст" и аналогичными
#     ✅ Обычно выводы подразумевают под собой текстовый ответ (можно писать markdown, latex).
#     ✅ Сопутствующие изображения, графики, таблички - приветствуются!
#     ❌ При отсутствии выводов задание не засчитается на полный балл

# %% [markdown]
# # О задании
#
# Задание состоит в построении модели предсказания стоимости машины по её характеристикам. В рамках выполнения задания вы научитесь ансамблировать базовые модели с помощью бэггинга, блендинга и стекинга для решения задачи регрессии. Вы будете оценивать результаты полученных моделей, сравнивать их между собой и выбирать наиболее оптимальную конфигурацию.
#
# Баллы даются за выполнение отдельных пунктов. Задачи рекомендуется решать в том порядке, в котором они представлены в задании.
#
# Что входит в практическую работу:
#
# *  Загрузка и предобработка данных
# *  Построение и оптимизация бэггинга решающих деревьев
# *  Реализация блендинга
# *  Построение стекинга в различных вариациях, подбор гиперпараметров
# *  Сравнение моделей
#
#
# <font color='OrangeRed'>**Обратите внимание!**</font> Поиск гиперпараметров через GridSearchCV может занимать продолжительное время, обычно до <font color='CornflowerBlue'>**10-15 минут**</font>

# %% [markdown]
# --------

# %% [markdown]
# В домашнем задании вам предлагается поработать с датасетом, который представляет собой данные о подержанных автомобилях, продаваемых в Великобритании. Он включает в себя характеристики автомобилей (пробег, год выпуска, тип двигателя и т. п.) и их цену (целевая переменная)
#
# [Описание датасета на kaggle](https://www.kaggle.com/datasets/muhammadawaistayyab/used-cars-prices-in-uk)

# %% [markdown]
# Прежде чем начать, импортируем некоторые модули и загрузим данные

# %%
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
! gdown 1Cdek-lsS3-XiDFtD5PzgXNsy3gvd_Rd-

# %% [markdown]
# ##  <font color='DarkOrange'>**Задача 1**</font>
#
# Подготовка данных
#
# Считайте датасет и предобработайте его:
# 1. Удалите ненужные столбцы: `'Unnamed: 0'`, `'Service history'`, `'title'`
# 2. Заполните пропуски в вещественных переменных. Пустые значения в поле `Previous Owners` заполните `0`, остальные поля заполните `средними значениями`
# 3. Обработайте `категориальные переменные:` объедините редкие классы в `"Other"`, после этого преобразуйте `категориальные переменные` в вещественные с помощью [pd.get_dummies()](https://pandas.pydata.org/docs/reference/api/pandas.get_dummies.html) или [One-Hot Encoder](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html)
#     * Обратите внимание на поле `Engine`. Чем оно отличается от `Fuel type` или `Body type`?
# 4. Разбейте весь датасет на `train/test` в пропорции `80/20`, зафиксируйте `random_state=42`
#     * Для `X_train`, `X_test`, `y_train`, `y_test` обновите индексы через `df.reset_index(drop=True)`

# %%
# Ваш код

# %% [markdown]
# <font color='MediumOrchid'>**Ваши выводы тут:**</font>

# %% [markdown]
#  ## <font color='DarkOrange'>**Задача 2**</font>
#
# Постройте бэггинг решающих деревьев

# %% [markdown]
# Постройте бэггинг с решающими деревьями для задачи регрессии
#
# * Используйте [BaggingRegressor](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.BaggingRegressor.html) из sklearn
# * Используйте параметры по умолчанию, зафиксировав `random_state=42`.
# * Обучите ансамбль на тренировочных данных
# * сделайте предсказание на тесте
# * выведите метрики RMSE и MAPE

# %%
# Ваш код

# %% [markdown]
#  Подберите оптимальные гиперпараметры с помощью [GridSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html) для бэггинга
#
# "Пробегитесь" по следующим параметрам:
# * `n_estimators: [10, 25, 50, 100, 200]`
# * `max_features: [0.2, 0.5, 0.7, 1.0]`
# * `max_samples: [0.5, 0.75, 1.0]`
# * `estimator__max_depth: [4, 6, 8, 10, 20, None]` — этот параметр оптимизирует глубину базового алгоритма (дерева)
#
# В качестве метрики оптимизации для GridSearchCV используйте `MSE`, для этого при инициализации `GridSearchCV()` используйте параметр `scoring='neg_mean_squared_error'`

# %%
# Ваш код

# %% [markdown]
#  Почему в `scoring` выше используется `отрицательное MSE `(neg_mean_squared_error), а не просто `MSE`?

# %% [markdown]
# <font color='MediumOrchid'>**Ваши выводы тут:**</font>

# %% [markdown]
#  Обучите модель с лучшими параметрами.
# Насколько улучшилось качество модели по сравнению с моделью с параметрами по умолчанию?

# %%
# Ваш код

# %% [markdown]
# <font color='MediumOrchid'>**Ваши выводы тут:**</font>

# %% [markdown]
# ## <font color='DarkOrange'>**Задача 3**</font>
#
# Постройте блендинг

# %% [markdown]
# Постройте 3 базовые модели
# * Линейная регрессия
# * kNN
# * Решающее дерево (зафиксируйте random_state=42)
#
# Проверьте модели:
#
# * Обучите модели на всём обучающем датасете.
# * Оцените качество моделей `(RMSE / MAPE)` на тесте

# %%
# Ваш код

# %% [markdown]
#  Разделите обучающий датасет на 2 подвыборки в соотношении 80/20: одна будет использована для обучения базовой модели `(X_base_train, y_base_train)`, другая для <font color='CornflowerBlue'>**мета-модели**</font> `(X_meta_train, y_meta_train)`

# %%
# Ваш код

# %% [markdown]
#  Обучите блендинг и оцените его качество
# 1. Обучите базовые модели на `X_base_train`
# 2. Сделайте предсказания базовых моделей на `X_meta_trai`n. Объедините все предсказания в один `DataFrame`, замените исходный `X_meta_train` на полученный `df` из прогнозов базовых моделей
# 3. Обучите мета-модель — `линейную регрессию` на обновлённом `X_meta_train`
# 4. Сделайте прогнозы базовых моделей на `X_test`. Объедините все прогнозы в один `DataFrame` — `X_meta_test`
# 5. Сделайте прогноз мета-модели на `X_meta_test`, оцените качество полученной модели с помощью `y_test`
#
# <font color='LightSteelBlue'>**Подсказка.**</font> При возникновении трудностей обратитесь к семинару

# %%
# Ваш код

# %% [markdown]
#  Оцените качество итоговой модели.
# Сравните её с базовыми моделями и с бэггингом решающих деревьев

# %%
# Ваш код

# %% [markdown]
# <font color='MediumOrchid'>**Ваши выводы тут:**</font>

# %% [markdown]
# ## <font color='DarkOrange'>**Задача 4**</font>
#
# Постройте стекинг

# %% [markdown]
#  Обучите стекинг
# 1. Воспользуйтесь готовым классом [StackingRegressor](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.StackingRegressor.html) из sklearn
# 2. В качестве базовых моделей инициализируйте `линейную регрессию, kNN, решающее дерево`
# 3. В качестве мета-модели (`final_estimator`) используйте `линейную регрессию`
# 4. Обучите построенную модель на `X_train`, сделайте прогнозы на `X_test`

# %%
# Ваш код

# %% [markdown]
#  Оцените качество полученной модели.
# Сравните его с базовыми моделями, с бэггингом решающих деревьев и с блендингом по RMSE и MAPE

# %%
# Ваш код

# %% [markdown]
# <font color='MediumOrchid'>**Ваши выводы тут:**</font>

# %% [markdown]
#  Добавьте в список базовых моделей бэггинг, полученный ранее.
# Обучите новую модель и оцените её качество

# %%
# Ваш код

# %% [markdown]
#  Попробуйте подобрать гиперпараметры для решающего дерева с помощью `GridSearchCV`
#
# Оптимизируйте `max_depth`, `min_samples_split`, `max_features` на всём `X_train`
#
# Получилось ли вырасти в качестве отдельной для решающего дерева? А на всём стекинге?

# %%
# Ваш код

# %% [markdown]
# <font color='MediumOrchid'>**Ваши выводы тут:**</font>

# %% [markdown]
# Измените мета-модель.
# Попробуйте в качестве мета-модели взять любой другой ранее изученный алгоритм.
#
# Как изменилось качество модели?

# %%
# Ваш код

# %% [markdown]
# <font color='MediumOrchid'>**Ваши выводы тут:**</font>

# %% [markdown]
# Подберите гиперпараметры.
#
# Попробуйте подобрать также гиперпараметры для базовых моделей kNN и линейной регрессии и новой мета-модели
#
# Получилось ли повысить качество?

# %%
# Ваш код

# %% [markdown]
# <font color='MediumOrchid'>**Ваши выводы тут:**</font>

# %% [markdown]
# ## <font color='DarkOrange'>**Задача 5**</font>
#
# Сделайте выводы по моделям:
#
# 1.  У какого ансамбля получилась самая высокая точность по метрикам RMSE и MAPE?
#
# 2.  Как вы оцениваете качество этой модели? Почему MAPE может оставаться относительно высоким?
#
# 3.  Какие преимущества и недостатки у  каждого из ансамблей? (бэггинга, блендинга, стекинга)

# %%
# Ваш код

# %% [markdown]
# <font color='MediumOrchid'>**Ваши выводы тут:**</font>

# %% [markdown]
# ## <font color='MediumSeaGreen'>**Бонус**</font>
#
# Напишие свой любимый фильм/мультфильм/сериал/пр.

# %% [markdown]
# <font color='MediumOrchid'>**Ваши выводы тут:**</font>
